# %% [markdown]
# # Changes done

# %% [markdown]
# ## The Machine Learning technique: change linear model (linear regression) for another ML technique that you believe could improve the price prediction, in a comment explain your choice.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# I change the model to the Ridge regression model, and explain my choice.

# %% [markdown]
# ## The market: from NASDAQ to S&P 500.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# In the precheck, I change the contest type to SP500.
#
# ![image.png](data:image/png;base64,...)
#
# Also in the strategy, I change the competition type to SP500.

# %% [markdown]
# ## The assets: include a minimum of 20 assets, in a comment explaining your choice.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# I selected various useful assets for the trading strategy, as they encompass different types of companies, ensuring that I maintain a diversified portfolio.

# %% [markdown]
# ## The variables: Include new variables which information that you believe could improve the price prediction, in a comment explain your choice.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# I decided to replace volatility with the Average True Range (ATR) to achieve greater accuracy, as ATR provides a more reliable measure of market volatility by incorporating price ranges and adapting better to changing market conditions.

# %% [markdown]
# # PnL and sharpe ratio

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# It displays the PnL (Equity) and the sharpe ratio

# %% [markdown]
# # Buy/sell code

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# This function defines the target classes for predicting whether the price will go up or down. It compares the current closing price with the future closing price (shifted by one time step) and assigns a class label of 1 if the price increases and 0 if it decreases. This provides a binary classification target for training predictive models.
