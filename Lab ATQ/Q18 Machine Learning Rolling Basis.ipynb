# %% [markdown]
# # Changes done

# %% [markdown]
# ## The Machine Learning technique

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# I change the model to the Ridge regression model, and explain my choice.

# %% [markdown]
# ## The market

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# In the precheck, I change the contest type to SP500.
#
# ![image.png](data:image/png;base64,...)
#
# Also in the strategy, I change the competition type to SP500.

# %% [markdown]
# ## The assets

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# I selected companies with a big capitalization.

# %% [markdown]
# ## The variables

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# I decided to replace volatility with the Average True Range (ATR) to achieve greater accuracy, as ATR provides a more reliable measure of market volatility by incorporating price ranges and adapting better to changing market conditions.

# %% [markdown]
# ## The targets

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# For predicting if price goes up or down.

# %% [markdown]
# ### Tests

# %% [markdown]
# #### Only long

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Only short

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Long and short

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Liquid assets

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# And this way, we can ensure we only trade with liquid assets.

# %% [markdown]
# # The Sharpe Ratio and the Plots (falta)

# %% [markdown]
# ## The sharpe ratio

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## The plots

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
